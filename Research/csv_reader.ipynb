# %%
import pandas as pd

# %%
df = pd.read_csv("google_maps_scrape_restaurants_in_gorakhpur.csv")
df
# Out:
#                                                  name  address  rating
# 0                   Baati Chokha Restaurant Gorakhpur      NaN     4.8
# 1                Rangrezza Restaurant & Banquet Hall.      NaN     4.5
# 2                       Kohinoor Restaurant Gorakhpur      NaN     4.6
# 3                10 Park Street Restaurant & Banquets      NaN     4.6
# 4    The Terai Restaurant, Banquet Hall & Rooftop Bar      NaN     4.2
# 5                         Zunoon Restaurant & Banquet      NaN     4.5
# 6                                          Shahanshah      NaN     4.1
# 7                     The Gorakhpur Family Restaurant      NaN     4.9
# 8   Akash Ganga The Terrace Restro Lounge - Bar in...      NaN     4.6
# 9                      Chawla Restaurant & Party Hall      NaN     3.9
# 10   The Currynights Restaurant & Banquet, Party Hall      NaN     4.2
# 11                  Baati Chokha Restaurant Gorakhpur      NaN     4.9
# ...
